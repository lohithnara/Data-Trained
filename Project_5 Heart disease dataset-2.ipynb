# %%
# Importing the libraries
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter('ignore')

# %%
# Reading the dataset from uci machine learning.
data_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.cleveland.data'
names_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/heart-disease.names'
columns = ['Age','sex','cp','trestbps','chol','fbs','restecg','thalach','exang','oldpeak','slope','ca','thal','num']
df = pd.read_csv(data_url,sep = ',',names = columns)

# %%
# Getting information of the dataset
df
# Out:
#       Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..    ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 0      3.0  0.0  6.0    0
# ...

# %%
df.head()
# Out:
#     Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  63.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  67.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  67.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  37.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  41.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca thal  num
# 0    3.0  0.0  6.0    0
# 1    2.0  3.0  3.0    2
# 2    2.0  2.0  7.0    1
# 3    3.0  0.0  3.0    0
# 4    1.0  0.0  3.0    0

# %%
df.tail()
# Out:
#       Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 298  45.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  68.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  57.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  57.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  38.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca thal  num
# 298    2.0  0.0  7.0    1
# 299    2.0  2.0  7.0    2
# 300    2.0  1.0  7.0    3
# 301    2.0  1.0  3.0    1
# 302    1.0    ?  3.0    0

# %%
df.isnull().sum()
# Out:
# Age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %%
#Computing mean,count,etc. characteristics
df.describe()
# Out:
#               Age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope         num
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.937294
# ...

# %%
#  columns of the data
df.columns
# Out:
# Index(['Age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %%
#Checking feature information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Age       303 non-null    float64
#  1   sex       303 non-null    float64
#  2   cp        303 non-null    float64
#  3   trestbps  303 non-null    float64
#  4   chol      303 non-null    float64
#  5   fbs       303 non-null    float64
#  6   restecg   303 non-null    float64
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    float64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    float64
#  11  ca        303 non-null    object
#  12  thal      303 non-null    object
#  13  num       303 non-null    int64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
df.corr()
# Out:
#                Age       sex        cp  trestbps      chol       fbs  \
# Age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# sex      -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fbs       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# num       0.222853  0.224469  0.407075  0.157754  0.070909  0.059186
#
#            restecg   thalach     exang   oldpeak     slope       num
# ...

# %%
df.shape
# Out:
# (303, 14)

# %%
# lets change the heart disease types 1to 4 to 1
df.loc[df['num'] > 0 , 'num'] =1

df.loc[(df.Age >= 29) & (df.Age < 40), 'Age'] = 1
df.loc[(df.Age >= 40) & (df.Age < 55) , 'Age'] = 2
df.loc[(df.Age >= 55) , 'Age'] = 3

# %%
# convert to number
df.ca = pd.to_numeric(df.ca,errors='coerce').fillna(0)
df.thal = pd.to_numeric(df.thal,errors='coerce').fillna(0)

# %%
df
# Out:
#      Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    3.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1    3.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2    3.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3    1.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4    2.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
# ..   ...  ...  ...       ...    ...  ...      ...      ...    ...      ...
# 298  2.0  1.0  1.0     110.0  264.0  0.0      0.0    132.0    0.0      1.2
# 299  3.0  1.0  4.0     144.0  193.0  1.0      0.0    141.0    0.0      3.4
# 300  3.0  1.0  4.0     130.0  131.0  0.0      0.0    115.0    1.0      1.2
# 301  3.0  0.0  2.0     130.0  236.0  0.0      2.0    174.0    0.0      0.0
# 302  1.0  1.0  3.0     138.0  175.0  0.0      0.0    173.0    0.0      0.0
#
#      slope   ca  thal  num
# 0      3.0  0.0   6.0    0
# ...

# %%
df.head()
# Out:
#    Age  sex   cp  trestbps   chol  fbs  restecg  thalach  exang  oldpeak  \
# 0  3.0  1.0  1.0     145.0  233.0  1.0      2.0    150.0    0.0      2.3
# 1  3.0  1.0  4.0     160.0  286.0  0.0      2.0    108.0    1.0      1.5
# 2  3.0  1.0  4.0     120.0  229.0  0.0      2.0    129.0    1.0      2.6
# 3  1.0  1.0  3.0     130.0  250.0  0.0      0.0    187.0    0.0      3.5
# 4  2.0  0.0  2.0     130.0  204.0  0.0      2.0    172.0    0.0      1.4
#
#    slope   ca  thal  num
# 0    3.0  0.0   6.0    0
# 1    2.0  3.0   3.0    1
# 2    2.0  2.0   7.0    1
# 3    3.0  0.0   3.0    0
# 4    1.0  0.0   3.0    0

# %%
# visualization of heatmap with correlation
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(), annot = True)
plt.show()

# %%
#  visualizing the age through distplot.
sns.distplot(df['Age'])
plt.show()

# %%
#  visualizing the sex through distplot.
sns.distplot(df['sex'])
plt.show()

# %%
#  visualizing the cp through distplot.
sns.distplot(df['cp'])
plt.show()

# %%
#  visualizing the trestbps through distplot.
sns.distplot(df['trestbps'])
plt.show()

# %%
sns.distplot(df['chol'])
plt.show()

# %%
# Finding Outliers of the data through boxplot
df.plot(kind='box',subplots = True, layout=(4,5),figsize = (10,20))
# Out:
# Age             AxesSubplot(0.125,0.71587;0.133621x0.16413)
# sex          AxesSubplot(0.285345,0.71587;0.133621x0.16413)
# cp            AxesSubplot(0.44569,0.71587;0.133621x0.16413)
# trestbps     AxesSubplot(0.606034,0.71587;0.133621x0.16413)
# chol         AxesSubplot(0.766379,0.71587;0.133621x0.16413)
# fbs            AxesSubplot(0.125,0.518913;0.133621x0.16413)
# restecg     AxesSubplot(0.285345,0.518913;0.133621x0.16413)
# thalach      AxesSubplot(0.44569,0.518913;0.133621x0.16413)
# exang       AxesSubplot(0.606034,0.518913;0.133621x0.16413)
# oldpeak     AxesSubplot(0.766379,0.518913;0.133621x0.16413)
# slope          AxesSubplot(0.125,0.321957;0.133621x0.16413)
# ca          AxesSubplot(0.285345,0.321957;0.133621x0.16413)
# thal         AxesSubplot(0.44569,0.321957;0.133621x0.16413)
# num         AxesSubplot(0.606034,0.321957;0.133621x0.16413)
# dtype: object

# %%
# Visualizing the data through Histogram.
df.hist(figsize=(20,20),grid=True,layout = (4,4),bins=30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f86f50962d0>,
# ...
#       dtype=object)

# %%
# Visualizing the Age data through countplot 
plt.figure(figsize=(15,10))
sns.countplot(df['Age'])
plt.show()

# %%
# Visualizing the sex data by count plot
plt.figure(figsize=(5,5))
sns.countplot(df['sex'])
plt.show()

# %%
#  visualizing the cp through countplot.
sns.countplot(df['cp'])
plt.show()

# %%
#  visualizing the num through countplot.
sns.countplot(df['num'])
plt.show()

# %%
# visualizing the age and sex through barplot.
plt.figure(figsize=(20,10))
sns.barplot(df['Age'],df['sex'])
plt.show()

# %%
# Visualizing the age through violin plot.
sns.violinplot(df['Age'])

# %%
# Visualizing the cp through violin plot.
sns.violinplot(df['cp'])

# %%
sns.pairplot(df)
plt.show()

# %%
df1 = df.drop(columns = ['trestbps','chol','fbs','restecg','thalach'])
df1
# Out:
#      Age  sex   cp  exang  oldpeak  slope   ca  thal  num
# 0    3.0  1.0  1.0    0.0      2.3    3.0  0.0   6.0    0
# 1    3.0  1.0  4.0    1.0      1.5    2.0  3.0   3.0    1
# 2    3.0  1.0  4.0    1.0      2.6    2.0  2.0   7.0    1
# 3    1.0  1.0  3.0    0.0      3.5    3.0  0.0   3.0    0
# 4    2.0  0.0  2.0    0.0      1.4    1.0  0.0   3.0    0
# ..   ...  ...  ...    ...      ...    ...  ...   ...  ...
# 298  2.0  1.0  1.0    0.0      1.2    2.0  0.0   7.0    1
# 299  3.0  1.0  4.0    0.0      3.4    2.0  2.0   7.0    1
# 300  3.0  1.0  4.0    1.0      1.2    2.0  1.0   7.0    1
# 301  3.0  0.0  2.0    0.0      0.0    2.0  1.0   3.0    1
# 302  1.0  1.0  3.0    0.0      0.0    1.0  0.0   3.0    0
#
# [303 rows x 9 columns]

# %%
# modeling

X = df1.drop('num',axis=1)
y = df1['num']

# %%
# splitting the data into training and testing datasets
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42,shuffle=True)
regressor = LogisticRegression()

# %%
# Using logistic regression to the model because the target variable contains as categorical values
regressor.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# predicted values of the test dataset
y_pred = regressor.predict(X_test)

# %%
# score of the training dataset and testing dataset
regressor.score(X_test,y_test)
regressor.score(X_train,y_train)
# Out:
# 0.8160377358490566

# %%
# Accuracy of Predicted dataset.
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, y_pred,labels=[0,1])
confusion_matrix
# Out:
# array([[40,  8],
#        [ 9, 34]])

# %%
# Finding the confusion matrix and classification report
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.83      0.82        48
#            1       0.81      0.79      0.80        43
#
#     accuracy                           0.81        91
#    macro avg       0.81      0.81      0.81        91
# weighted avg       0.81      0.81      0.81        91

# %%
# Finding Croos-validation score of the model
from sklearn.model_selection import cross_val_score
cross_val_score(LogisticRegression(),X,y,cv=5,scoring='accuracy').mean()
# Out:
# 0.8281967213114754

# %%
# saving the model as a pickle in the file.
from sklearn.externals import joblib

joblib.dump(LogisticRegression,'Heart disease dataset.pkl')
# Out:
# ['Heart disease dataset.pkl']
